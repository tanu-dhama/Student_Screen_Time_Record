# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
var = pd.read_csv(r'C:\Users\HASOUB\Downloads\Indian_Kids_Screen_Time.csv')
var
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %%
var.head()
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                               0.39
# 4                        True                               0.49
#
#            Health_Impacts Urban_or_Rural
# 0  Poor Sleep, Eye Strain          Urban
# 1              Poor Sleep          Urban
# 2              Poor Sleep          Urban
# 3                     NaN          Urban
# ...

# %%
var.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                9712 non-null   int64
#  1   Gender                             9712 non-null   object
#  2   Avg_Daily_Screen_Time_hr           9712 non-null   float64
#  3   Primary_Device                     9712 non-null   object
#  4   Exceeded_Recommended_Limit         9712 non-null   bool
#  5   Educational_to_Recreational_Ratio  9712 non-null   float64
#  6   Health_Impacts                     6494 non-null   object
#  7   Urban_or_Rural                     9712 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 540.7+ KB

# %%
var.describe()
# Out:
#                Age  Avg_Daily_Screen_Time_hr  \
# count  9712.000000               9712.000000
# mean     12.979201                  4.352837
# std       3.162437                  1.718232
# min       8.000000                  0.000000
# 25%      10.000000                  3.410000
# 50%      13.000000                  4.440000
# 75%      16.000000                  5.380000
# max      18.000000                 13.890000
#
#        Educational_to_Recreational_Ratio
# count                        9712.000000
# mean                            0.427226
# std                             0.073221
# min                             0.300000
# 25%                             0.370000
# 50%                             0.430000
# 75%                             0.480000
# max                             0.600000

# %%
var.isnull().sum()
# Out:
# Age                                     0
# Gender                                  0
# Avg_Daily_Screen_Time_hr                0
# Primary_Device                          0
# Exceeded_Recommended_Limit              0
# Educational_to_Recreational_Ratio       0
# Health_Impacts                       3218
# Urban_or_Rural                          0
# dtype: int64

# %%
var.head(10)
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
# 5   14  Female                      4.88     Smartphone
# 6   17    Male                      2.97             TV
# 7   10    Male                      2.74             TV
# 8   14    Male                      4.61         Laptop
# 9   18    Male                      3.24         Tablet
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                               0.39
# ...

# %% [markdown]
# # Manage missing value

# %%
var.fillna(method='bfill',inplace=True)
# Out:
# C:\Users\HASOUB\AppData\Local\Temp\ipykernel_12060\2886769540.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   var.fillna(method='bfill',inplace=True)

# %%
var.head(20)
# Out:
#     Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0    14    Male                      3.99     Smartphone
# 1    11  Female                      4.61         Laptop
# 2    18  Female                      3.73             TV
# 3    15  Female                      1.21         Laptop
# 4    12  Female                      5.89     Smartphone
# 5    14  Female                      4.88     Smartphone
# 6    17    Male                      2.97             TV
# 7    10    Male                      2.74             TV
# 8    14    Male                      4.61         Laptop
# 9    18    Male                      3.24         Tablet
# 10   18    Male                      3.53         Tablet
# 11   15  Female                      4.94             TV
# 12   12    Male                      4.59     Smartphone
# 13   11    Male                      6.08             TV
# 14   15    Male                      6.15     Smartphone
# ...

# %% [markdown]
# # We have split Health_impacts in a list than explode dataframe to have only one Healt_impacts per row for each movie

# %%
var['Health_Impacts'] = var['Health_Impacts'].str.split(', ')
var = var.explode('Health_Impacts').reset_index()
var.head()
# Out:
#    index  Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      0   14    Male                      3.99     Smartphone
# 1      0   14    Male                      3.99     Smartphone
# 2      1   11  Female                      4.61         Laptop
# 3      2   18  Female                      3.73             TV
# 4      3   15  Female                      1.21         Laptop
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.42
# 2                        True                               0.30
# 3                        True                               0.32
# 4                       False                               0.39
#
#   Health_Impacts Urban_or_Rural
# 0     Poor Sleep          Urban
# 1     Eye Strain          Urban
# 2     Poor Sleep          Urban
# 3     Poor Sleep          Urban
# ...

# %%
var.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15056 entries, 0 to 15055
# Data columns (total 9 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   index                              15056 non-null  int64
#  1   Age                                15056 non-null  int64
#  2   Gender                             15056 non-null  object
#  3   Avg_Daily_Screen_Time_hr           15056 non-null  float64
#  4   Primary_Device                     15056 non-null  object
#  5   Exceeded_Recommended_Limit         15056 non-null  bool
#  6   Educational_to_Recreational_Ratio  15056 non-null  float64
#  7   Health_Impacts                     15056 non-null  object
#  8   Urban_or_Rural                     15056 non-null  object
# dtypes: bool(1), float64(2), int64(2), object(4)
# memory usage: 955.8+ KB

# %% [markdown]
# # Data visualization

# %%
var.head(10)
# Out:
#    index  Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      0   14    Male                      3.99     Smartphone
# 1      0   14    Male                      3.99     Smartphone
# 2      1   11  Female                      4.61         Laptop
# 3      2   18  Female                      3.73             TV
# 4      3   15  Female                      1.21         Laptop
# 5      3   15  Female                      1.21         Laptop
# 6      4   12  Female                      5.89     Smartphone
# 7      4   12  Female                      5.89     Smartphone
# 8      5   14  Female                      4.88     Smartphone
# 9      6   17    Male                      2.97             TV
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.42
# 2                        True                               0.30
# ...

# %%
sns.set_style("whitegrid")

# %% [markdown]
# # which has the highest gender in gender column?

# %%
sns.catplot(y='Gender',data=var,kind='count',order=var['Gender'].value_counts().index,color='g')
plt.show()

# %% [markdown]
# # What primary_device got the highest popularity ? what's its health impacts

# %%
var[var['Primary_Device'] == var['Primary_Device'].max()]
# Out:
#        index  Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 15         9   18    Male                      3.24         Tablet
# 16         9   18    Male                      3.24         Tablet
# 17        10   18    Male                      3.53         Tablet
# 30        22    9  Female                      1.63         Tablet
# 32        24    8    Male                      3.19         Tablet
# ...      ...  ...     ...                       ...            ...
# 14939   9636   10    Male                      4.02         Tablet
# 14986   9667    8  Female                      0.89         Tablet
# 15005   9678   12    Male                      5.32         Tablet
# 15017   9685    9    Male                      5.58         Tablet
# 15021   9689    8    Male                      1.90         Tablet
#
#        Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 15                           True                               0.48
# ...

# %% [markdown]
# # What primary_device got the lowest popularity ? what's its health impacts

# %%
var[var['Primary_Device'] == var['Primary_Device'].min()]
# Out:
#        index  Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 2          1   11  Female                      4.61         Laptop
# 4          3   15  Female                      1.21         Laptop
# 5          3   15  Female                      1.21         Laptop
# 13         8   14    Male                      4.61         Laptop
# 14         8   14    Male                      4.61         Laptop
# ...      ...  ...     ...                       ...            ...
# 15012   9682   16  Female                      6.69         Laptop
# 15013   9682   16  Female                      6.69         Laptop
# 15014   9682   16  Female                      6.69         Laptop
# 15020   9688   11  Female                      3.17         Laptop
# 15028   9694   15  Female                      7.09         Laptop
#
#        Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 2                            True                               0.30
# ...

# %% [markdown]
# # what is the health impact ?

# %%
var['Health_Impacts'].hist()
plt.title('Health impact distribution')
plt.show()

# %% [markdown]
# # which area most use of device urban_or_rural area?

# %%
var['Urban_or_Rural'].hist()
plt.title('Urban_or_Rural area distribution')
plt.show()

# %%
Conclusion 
Q.1 : which has the highest gender in gender column?
We have the male gender from our dataset

Q.2: What primary_device got the highest popularity ? what's its health impacts
we got the tablet  as highest popularity and its health imapact is Poor sleep ,anxiety,eye strain

Q.3 :What primary_device got the lowest popularity ? what's its health impacts
We got the laptop as lowest popularity and its health impact is Poor sleep ,Anxiety

Q.4 :what is the health impact ?
we got the most health impact is poor sleep from our dataset

Q.5 :which area most use of device urban_or_rural area?
We recieve the urban area most used primary device from our dataset
